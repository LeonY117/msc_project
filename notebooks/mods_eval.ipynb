# %% [markdown]
# # MOD EVAL
# Repo: https://github.com/bborja/mods_evaluation
#
# Package requirements:
# *
# *
# *
# *
#
# Eval code:
# * from: `ShorelineNet_pytorch/evaluation/mod_eval`
# * to: `./mod_eval`
#
# Results folder:
# * from: `ShorelineNet_pytorch/results/name`
# * to: `./results/name`
#
# MODS folder:
# * from: `ShorelineNet_pytorch/dataset/mods.zip`
# * to: `./mods`
